# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import sqlite3 as sq3
import UCSC_spec_db_interaction as UCSC_db
import sys
import os
import scipy.signal
from astropy.io import fits
from dust_extinction.parameter_averages import F99
import astropy.units as u
import pandas as pd
import glob
import copy
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Query Database for a specific host and grab apertures with physical size

# %%
os.chdir('/Users/msiebert/Documents/UCSC/Research/UCSC_spec_database/UCSC_spec_db')
#ran:
# #20180710
test_query = "SELECT * from SPECTRA where OBJECT like '%15pr%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%15cge%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%17bs%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%17drh%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"

# #20180611
test_query = "SELECT * from SPECTRA where OBJECT like '%17hmf%' and FILENAME like '%combined-20180611%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%16-efw%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%15mg%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%18jh%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%17gfl%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"

# #20180509
test_query = "SELECT * from SPECTRA where OBJECT like '%17gav%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%17hlt%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"

# #20180115
test_query = "SELECT * from SPECTRA where OBJECT like '%18kl%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%17jxd%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and AP_SIZE < 2 and FILENAME not like '%_SN%'"
test_query = "SELECT * from SPECTRA where FILENAME like '%17dzg%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%16ez%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
# ## test_query = "SELECT * from SPECTRA where OBJECT like '%16htm%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
# ## test_query = "SELECT * from SPECTRA where OBJECT like '%16agf%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"

# #20180114
test_query = "SELECT * from SPECTRA where OBJECT like '%15mt%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%15pn%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%17hoo%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%17hju%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%17glq%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"

# # #20170823
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%16esh%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD) and FILENAME not like '%_SN%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%16cuv%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%15cfn%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where FILENAME like '%16cvc%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%16dnp%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%15bzz%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%16bwu%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%CSS161013%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
test_query = "SELECT * from SPECTRA where OBJECT like '%16grz%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"

# #20171115
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%16bba%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"
# ##test_query = "SELECT * from SPECTRA where OBJECT like '%16ije%' and FILENAME like '%combined%' and (AP_UNIT = 'kpc' or IS_KRON_RAD)"

# #20170402
test_query = "SELECT * from SPECTRA where OBJECT like '%15fa%' and FILENAME like '%combined%' and FILENAME not like '%_SN.fits%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15hg%' and FILENAME like '%combined%' and FILENAME not like '%_SN.fits%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15jt%' and FILENAME like '%combined%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15la%' and FILENAME like '%combined%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15lu%' and FILENAME like '%combined%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15mi%' and FILENAME like '%combined%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15nr%' and FILENAME like '%combined%'"
test_query = "SELECT * from SPECTRA where OBJECT like '%15so%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%16av%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%16lg%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%16cpu%' and FILENAME like '%combined%' and FILENAME not like '%_SN.fits%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%15bdr%' and FILENAME like '%combined%' and FILENAME not like '%_SN%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%15zn%' and FILENAME like '%combined%' and FILENAME not like '%_SN%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%16cqa%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%16el%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%PSNJ0859349%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%PSNJ1602512%' and FILENAME like '%combined%'"
# test_query = "SELECT * from SPECTRA where OBJECT like '%PSNJ1628383%' and FILENAME like '%combined%'"

#20180206
test_query = "SELECT * from SPECTRA where OBJECT like '%2016afk%' and FILENAME like '%combined%' and FILENAME like '%rkron%'"


spectra = UCSC_db.query_and_plot(test_query)
# Out:
# Collecting data from /Users/msiebert/Documents/UCSC/Research/UCSC_spec_database/UCSC_SPEC_DATA_DEV.db ...
# SN2016afk-combined-20180207_ap9_6.803_rkron.fits
# 1 Total Spectra found

# %% [markdown]
# # Get MW dust and correct spectra using Rv = 3.1 (doing in firefly now)

# %%
os.chdir('/Users/msiebert/Documents/UCSC/Research/firefly_release/')
from python import firefly_dust
# sn_dust = {}
# for spec in spectra:
#     if spec.meta_dict['OBJECT'] not in sn_dust:
#         ebv_mw = firefly_dust.get_dust_radec(spec.meta_dict['RA'],spec.meta_dict['DEC'],'ebv')
#         sn_dust[spec.meta_dict['OBJECT']] = ebv_mw
#         print (spec.meta_dict['OBJECT'], ebv_mw)
# ext = F99(Rv=3.1)
# for spec in spectra:
#     if spec.meta_dict['OBJECT'] in sn_dust:
#         print ('Correcting MW ext for', spec.meta_dict['FILENAME'])
#         spec.flux_dered_mw = spec.flux/ext.extinguish(spec.wavelength*u.AA, Av=3.1*sn_dust[spec.meta_dict['OBJECT']])
#         spec.err_dered_mw = spec.err/ext.extinguish(spec.wavelength*u.AA, Av=3.1*sn_dust[spec.meta_dict['OBJECT']])

# %% [markdown]
# # Take the largest aperture
# # Estimate a pseudo continuum using a median filter
# # Measure the Balmer decrement with gaussian line fitting
#
# # Ignoring for now

# %%
os.chdir('/Users/msiebert/Documents/UCSC/Research/nebular_fitting/')
import line_fitting_tools as tools

# for spec in spectra:
#     spec.wave_dered = spec.wavelength/(1.+z)
#     if 'rkron' in spec.meta_dict['FILENAME']:
#         flux_filt = scipy.signal.medfilt(spec.flux_dered_mw, kernel_size=41) #caveat: assuming no uncertainty here
#         neb_flux = spec.flux_dered_mw-flux_filt
#         mgaus_solved, w_range, fit_lines = tools.fit_galaxy([spec.wave_dered, neb_flux, 3.*spec.err_dered_mw])
#         h_ratio = mgaus_solved[2]['H_a_6562']/mgaus_solved[2]['H_b_4861']
#         ebv_gal = tools.calc_ebv_from_H_decrement(h_ratio)
#         tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [3650, 3800])
#         tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [4750, 5100])
#         tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [6500, 6800])
#         print (spec.meta_dict['FILENAME'], h_ratio, ebv_gal)
        

#         for line in fit_lines:
#             if line.parent_line is None:
#                 print (line.name)
#                 print ('Amplitude:', np.round(line.a,4))
#                 print ('Velocity (km/s):', np.round(line.vel,4))
#                 print ('Velocity width(km/s):', np.round(line.v_width,2))
#                 if line.skew != None:
#                     print ('Skewness width(km/s):', np.round(line.skew,2))
#                 else:
#                     print ('Skewness width(km/s):', ' None')

# %%
# approx_z = 0.0456054

# for spec in spectra:
#     spec.wave_dered = spec.wavelength/(1.+approx_z)
#     wave_min = 3700
#     wave_max = 6800
#     roi = (spec.wavelength > wave_min) & (spec.wavelength < wave_max)
#     scale_factor = (1./np.amax(spec.flux[roi]))
#     spec.flux = spec.flux*scale_factor
#     spec.err = spec.err*scale_factor
#     flux_filt = scipy.signal.medfilt(spec.flux, kernel_size=41) #caveat: assuming no uncertainty here

#     neb_flux = spec.flux-flux_filt
#     fit_output  = tools.fit_lines([spec.wave_dered, neb_flux, 3.*spec.err],wave_range=[3700,6800], s_f = False)
#     mgaus_solved = fit_output[1]
#     w_range = fit_output[8]
#     neb_flux = fit_output[7]
#     fit_lines = fit_output[3]
#     tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [3650, 3800])
#     tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [4750, 5100])
#     tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [6500, 6800])
#     spec.flux_wo_em = neb_flux - (mgaus_solved[0])+flux_filt
#     plt.figure(figsize=[16,8])
#     plt.plot(spec.wave_dered, spec.flux_wo_em)
#     plt.show()

# %%
approx_z = 0.0456721094811905

for spec in spectra:
    spec.wave_dered = spec.wavelength/(1.+approx_z)
#     if 'rkron' in spec.meta_dict['FILENAME']:
    if '3.0_kpc' in spec.meta_dict['FILENAME'] and '_SN' not in spec.meta_dict['FILENAME']:
#     if '1.5_kpc' in spec.meta_dict['FILENAME'] and '_SN' not in spec.meta_dict['FILENAME']:
        wave_min = 3700
        wave_max = 6800
        roi = (spec.wavelength > wave_min) & (spec.wavelength < wave_max)
        scale_factor = (1./np.amax(spec.flux[roi]))
        spec.flux = spec.flux*scale_factor
        spec.err = spec.err*scale_factor
        flux_filt = scipy.signal.medfilt(spec.flux, kernel_size=41) #caveat: assuming no uncertainty here
        
        neb_flux = spec.flux-flux_filt
        fit_output  = tools.fit_lines([spec.wave_dered, neb_flux, 3.*spec.err],wave_range=[3700,6800], s_f = False)
        mgaus_solved = fit_output[1]
        w_range = fit_output[8]
        neb_flux = fit_output[7]
        fit_lines = fit_output[3]
        tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [3650, 3800])
        tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [4750, 5100])
        tools.plot_fit(w_range, mgaus_solved[1], fit_lines, xlim = [6500, 6800])
# Out:
# Fitting...

# %%
# plt.figure(figsize=[16,8])
# plt.plot(w_range, neb_flux_interp)
# plt.plot(w_range, mgaus_solved[0])
# plt.plot(w_range, neb_flux-mgaus_solved[0])
# plt.xlim([6500,6600])
# # plt.ylim([-.1,.3])
# plt.show()
# plt.figure(figsize=[16,8])
# plt.plot(w_range, neb_flux - (mgaus_solved[0])+flux_filt)
# # plt.xlim([6200,6800])
# # plt.ylim([.1,.3])
# plt.show()
# plt.figure(figsize=[16,8])
# plt.plot(w_range, neb_flux - (mgaus_solved[0])+flux_filt)
# plt.xlim([4000,6800])
# # plt.ylim([.1,.3])
# plt.show()

# %%
# good_lines_for_z = ['[O III]_a', 'H_a',  '[O II]_a']
# good_lines_for_z = ['[N II]_a', 'H_a',  '[O II]_a']
good_lines_for_z = ['[N II]_a', 'H_a',  '[S II]_a'] 
# good_lines_for_z = ['[O II]_a', 'H_a']
# good_lines_for_z = ['[N II]_a', '[O II]_a'] 
# good_lines_for_z = ['[O II]_a', '[N II]_a', '[S II]_a']
# good_lines_for_z = [ 'H_a',  '[S II]_a', '[O III]_a', '[O II]_a'] 
# good_lines_for_z = [ 'H_a',  '[S II]_a', '[O II]_a', '[N II]_a']
good_lines_for_z = ['[N II]_a', 'H_a',  '[O II]_a', '[S II]_a', '[O III]_a'] #one per element
# good_lines_for_z = [ 'H_a',  '[O II]_a', '[S II]_a', '[O III]_a']
# good_lines_for_z = []
z_array = []
for line in fit_lines:
    if line.parent_line is None:
        if line.name in good_lines_for_z:
            print (line.name) 
            print ('Amplitude:', np.round(line.a,4))
            print ('Velocity (km/s):', np.round(line.vel,4))
            print ('Velocity width(km/s):', np.round(line.v_width,2))
            center_wave = tools.calculate_wave_from_velocity(line.vel, line.rest_wave)
            print ('Center Wave (A):', center_wave*(1.+approx_z))
            real_z = (center_wave*(1.+approx_z)/line.rest_wave) - 1
            print ('Real z:', real_z)
            z_array.append(real_z)
if len(z_array) == 0:
    z = approx_z
else:
    z = np.average(z_array)
print ('Final z measurement for fitting: ', z)
# Out:
# [O III]_a
# Amplitude: 0.0506
# Velocity (km/s): -17.2814
# Velocity width(km/s): 189.93
# Center Wave (A): 5185.09602568429
# Real z: 0.04561183406685254
# [O II]_a
# Amplitude: 0.4698
# Velocity (km/s): -21.4731
# Velocity width(km/s): 169.59
# Center Wave (A): 3895.9286794085942
# Real z: 0.045597214250600704
# H_a
# Amplitude: 0.7993
# Velocity (km/s): 36.2959
# Velocity width(km/s): 153.02
# Center Wave (A): 6863.357359552378
# Real z: 0.04579871663612245
# [N II]_a
# Amplitude: 0.0743
# Velocity (km/s): 18.2183
# Velocity width(km/s): 190.73
# Center Wave (A): 6847.52936520425
# Real z: 0.04573565644798827
# [S II]_a
# Amplitude: 0.1613
# Velocity (km/s): 14.9437
# Velocity width(km/s): 179.46
# Center Wave (A): 7023.5440747783305
# Real z: 0.045724234085070536
# Final z measurement for fitting:  0.0456935310973269

# %%
import pyphot
host_ps1_df = pd.read_csv('/Users/msiebert/Documents/UCSC/Research/Foundation_Hosts/host_ps1_data.csv')
for spec in spectra:
#     if '1.5_kpc' in spec.meta_dict['FILENAME']:
    if 'rkron' in spec.meta_dict['FILENAME']:
        host_name = spec.meta_dict['FILENAME'].split('-')[0]
        if 'ASASSN' in host_name:
            host_name = 'ASASSN-'+host_name.split('ASASSN')[1].split('_')[0]
        if '_' in host_name:
            host_name = host_name.split('_')[0]
        if 'PTSS16' in host_name:
            host_name = 'PTSS-16efw'
        if 'SN2017hlt' in host_name:
            host_name = '2017hlt'
        if 'sn2018kl' in host_name:
            host_name = '2018kl'
        if 'AT2017hoo' in host_name:
            host_name = '2017hoo'
        if '2016afk' in host_name:
            host_name = '2016afk'
        host_ind = list(host_ps1_df['name'].values).index(host_name)
        r_int = host_ps1_df['rmag'][host_ind] - host_ps1_df['rext'][host_ind] #TODO:should use non-corrected?
        lib = pyphot.get_library()
        filt = 'SDSS_r'
        func = lib[filt]
        fflux = func.get_flux(spec.wavelength, spec.flux, axis = -1).value
        rmag = -2.5 * np.log10(fflux) - func.Vega_zero_mag
        print (rmag, r_int)
        r_diff = r_int - rmag
        scale = 10**(r_diff/(-2.5))
        fflux_new = func.get_flux(spec.wavelength, scale*spec.flux, axis = -1).value
        rmag_new = -2.5 * np.log10(fflux_new) - func.Vega_zero_mag
        print (rmag_new)
for spec in spectra:
    print (spec.meta_dict['FILENAME'])
    #firefly assumes flux units 10**(-15)
    spec.flux_scaled = scale*spec.flux/10**(-15)
#     spec.flux_wo_em_scaled = scale*spec.flux_wo_em/10**(-15)
    spec.err_scaled = scale*spec.err/10**(-15)
    plt.plot(spec.wavelength, spec.flux_scaled)
    plt.show()
# Out:
# Warning: assuming 1 angstrom units to unitless object.
# Warning: assuming 1 flam units to unitless object.
# -19.983933899027953 16.41629978942871
# Warning: assuming 1 angstrom units to unitless object.
# Warning: assuming 1 flam units to unitless object.
# 16.416299789428713
# SN2016afk-combined-20180207_ap9_6.803_rkron.fits

# %% [markdown]
# # Correct for host galaxy extinction (for now maybe better to fit host extinction with firefly)

# %%
# for spec in spectra:
#     print ('Correcting for host ext of E(B-V):', ebv_gal) 
#     spec.flux_dered_mw_gal = spec.flux_dered_mw/ext.extinguish(spec.wave_dered*u.AA, Av=3.1*ebv_gal)
#     spec.err_dered_mw_gal = spec.err_dered_mw/ext.extinguish(spec.wave_dered*u.AA, Av=3.1*ebv_gal)
#     plt.plot(spec.wave_dered, spec.flux)
#     plt.plot(spec.wave_dered, spec.flux_dered_mw_gal)
#     plt.show()

# %% [markdown]
# # Fit stellar continuum using firefly (hpf_mode = 'on' , and milky_way_reddening = True)

# %%
os.chdir('/Users/msiebert/Documents/UCSC/Research/firefly_release/')
from run import firefly
from run import read_firefly
from scipy.interpolate import splrep,splev

# %%
for spec in spectra:
    print (spec.meta_dict['FILENAME'], spec.meta_dict['OBJECT'])
#         firefly.main(spec.wavelength, spec.flux_scaled, spec.err_scaled, z, spec.meta_dict['RA'], 
#                      spec.meta_dict['DEC'], vdisp=135.89957, res=5000, input_file = spec.meta_dict['FILENAME'].split('.fits')[0], 
#                      clobber=True)
#     firefly.main(spec.wavelength, spec.flux_scaled, spec.err_scaled, z, spec.meta_dict['RA'], 
#                  spec.meta_dict['DEC'], vdisp=135.89957, res=5000, input_file = spec.meta_dict['FILENAME'].split('.fits')[0], 
#                  clobber=False)
#     firefly.main(spec.wavelength, spec.flux_dered_mw_gal, spec.err_dered_mw_gal, z, spec.meta_dict['RA'], 
#                  spec.meta_dict['DEC'], vdisp=135.89957, res=5000, input_file = spec.meta_dict['FILENAME'].split('.fits')[0], clobber=False)

    #using spectrum with em lines removed
#     firefly.main(spec.wavelength, spec.flux_scaled, spec.err_scaled, z, spec.meta_dict['RA'], 
#                  spec.meta_dict['DEC'], vdisp=135.89957, res=5000, input_file = spec.meta_dict['FILENAME'].split('.fits')[0], 
#                  clobber=True,clip_lines=True)
    firefly.main(spec.wavelength, spec.flux_scaled, spec.err_scaled, z, spec.meta_dict['RA'], 
                 spec.meta_dict['DEC'], vdisp=135.89957, res=5000, input_file = spec.meta_dict['FILENAME'].split('.fits')[0], 
                 clobber=True,clip_lines=False)
# Out:
# SN2016afk-combined-20180207_ap9_6.803_rkron.fits SN2016afk
#
# Starting firefly ...
#
#
# Output file:  /Users/msiebert/Documents/UCSC/Research/firefly_release/output/spFly-SN2016afk-combined-20180207_ap9_6.803_rkron.fits
#
# Clipping ['O-II', 'O-IIIa', 'O-IIIb', 'O-IIIc', 'H-β', 'S-II', 'Ha_N-II']
# E(B-V)_MW =  0.055502847
# getting the models, t= 1647455978.783455
# Corrects from dust attenuation and fitting, Dt= 24.53201413154602 seconds
# dust done, Dt= 33.35729622840881 seconds
# fitting done, Dt= 41.02194619178772 seconds
# Gets the best model, Dt= 41.02211093902588 seconds
#
# Done... total time: 43 seconds.

# %% [markdown]
# # Visualize continuum fits, remove large scale differences with median filter, save output to fits

# %%
os.chdir('/Users/msiebert/Documents/UCSC/Research/firefly_release/')
from run import firefly
from run import read_firefly
save=False
for spec in spectra:
    print (spec.meta_dict['FILENAME'])
    wave, flux, model_flux, params, og_data = read_firefly.main('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
    hdu_fit = fits.open('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
    fit_head=hdu_fit[1].header
#     fit data=hdu_fit[1].data
#     neb_emission = flux - model_flux

    #trimming edges to avoid bad parts of fit
    wave = wave[np.where(wave!=0)[0]]
    flux = flux[np.where(wave!=0)[0]]
    model_flux = model_flux[np.where(wave!=0)[0]]

    buff = 10
#         print (np.where(model_flux!=0)[0])
#         wave = wave[np.where(model_flux!=0)[0]]
#         flux = flux[np.where(model_flux!=0)[0]]
#         model_flux = model_flux[np.where(model_flux!=0)[0]]
    wave = wave[buff:-buff]
    flux = flux[buff:-buff]
    model_flux = model_flux[buff:-buff]

    waveb = wave[0]
    waver = wave[-1]

    wave_og = og_data[0][(og_data[0]>=waveb) &(og_data[0]<=waver)]
    flux_og = og_data[1][(og_data[0]>=waveb) &(og_data[0]<=waver)]
    
    spline=splrep(wave,model_flux,k=1)
    interp_model_flux=splev(wave_og,spline)
    
#     print (len(flux_og),len(flux),len(model_flux), len(interp_model_flux))
    plt.figure(figsize=[16,8])
    plt.plot(wave_og,flux_og)
    plt.plot(wave,flux)
    plt.plot(wave,model_flux)
    plt.plot(wave_og,interp_model_flux)
#     plt.xlim(3700,8000)
#     plt.xlim(6500,6800)
#     plt.ylim(0,.07)
    plt.show()

    neb_emission = flux_og - interp_model_flux

    meta_dict_spec = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0] +'-spec'}
    meta_dict_model = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0]+ '-model'}
    db_spec = UCSC_db.spectrum(wavelength=wave_og, flux=flux_og, meta_dict=meta_dict_spec)
    db_spec_model = UCSC_db.spectrum(wavelength=wave_og, flux=interp_model_flux, meta_dict=meta_dict_model)
    UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [6400, 6800], plot_region = [3550, 7900], legend = True, rescale=False, cont_subtract=False)
    UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [6400, 6800], legend = False, rescale=False, cont_subtract=False)
    UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [4800, 5030], legend = False, rescale=False, cont_subtract=False)
    UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [3550, 4150], legend = False, rescale=False, cont_subtract=False)

    meta_dict_neb = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0]+ '-nebular'}
    db_spec_neb = UCSC_db.spectrum(wavelength=wave_og, flux=neb_emission, meta_dict=meta_dict_neb)
    UCSC_db.host_line_plots([db_spec_neb], 0, region = [6400, 6800], plot_region = [3550, 7900], legend = True, rescale=False)
    UCSC_db.host_line_plots([db_spec_neb], 0, region = [6400, 6800], legend = False, rescale=False)
    UCSC_db.host_line_plots([db_spec_neb], 0, region = [4800, 5030], legend = False, rescale=False)
    UCSC_db.host_line_plots([db_spec_neb], 0, region = [3550, 4150], legend = False, rescale=False)

    plt.figure(figsize=[15,8])
    flux_filt = scipy.signal.medfilt(db_spec_neb.flux, kernel_size=201)
    print ('Median continuum: ', np.median(db_spec.flux))
    print ('Median residual: ', np.median(np.absolute(flux_filt)))
    print ('Residual fraction: ', 100*np.median(np.absolute(flux_filt))/np.median(db_spec.flux), '%')
    plt.plot(db_spec_neb.wavelength, db_spec_neb.flux)
    plt.plot(db_spec_neb.wavelength, flux_filt)
    # plt.xlim(6000,8000)
#     plt.ylim(-.05,.05)
    plt.show()

    plt.figure(figsize=[15,8])
    final_neb_flux = db_spec_neb.flux - flux_filt
    plt.plot(db_spec_neb.wavelength, final_neb_flux)
    # plt.xlim(6000,8000)
#     plt.ylim(-.01,.105)
    plt.xlim(3600,5100)
    plt.axhline(y=0.0, color='k')
    plt.show()

    if save:
        outhdu=fits.PrimaryHDU([db_spec_neb.wavelength,final_neb_flux])
        hdul=fits.HDUList(outhdu)
        hdul[0].header=fit_head
        hdul[0].verify('fix') 
        hdul[0].header.set('redshift', z)
        for key in spec.meta_dict.keys():
            hdul[0].header.set(key, spec.meta_dict.get(key,'N/A'))
    #     hdul[0].header.set('ebv_host', ebv_gal)
    #     hdul[0].header.set('h_ratio',h_ratio)
        hdul.writeto('/Users/msiebert/Documents/UCSC/Research/Foundation_Hosts/analysis/host_nebular_emission_data/'+spec.meta_dict['FILENAME'].split('.fits')[0]+'-nebular.fits',overwrite=True)
        hdul.close()
# Out:
# SN2016afk-combined-20180207_ap9_6.803_rkron.fits
# age: 7.56 Gyr
# [Z/H]: -1.77 dex
# log M/Msun: 10.08
# E(B-V): 0.01 mag
# Median continuum:  0.5867790796972622
# Median residual:  0.009998317563516324
# Residual fraction:  1.7039321798375584 %

# %%
os.chdir('/Users/msiebert/Documents/UCSC/Research/firefly_release/')
from run import firefly
from run import read_firefly
save=True
for spec in spectra:
    if 'rkron' in spec.meta_dict['FILENAME'] and '_SN' not in spec.meta_dict['FILENAME']:
        print (spec.meta_dict['FILENAME'])
        wave, flux, model_flux, params, og_data = read_firefly.main('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
        hdu_fit = fits.open('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
        fit_head=hdu_fit[1].header
    #     fit data=hdu_fit[1].data
        neb_emission = flux - model_flux

        #trimming edges to avoid bad parts of fit
        wave = wave[np.where(wave!=0)[0]]
        flux = flux[np.where(wave!=0)[0]]
        model_flux = model_flux[np.where(wave!=0)[0]]

        buff = 10
    #         print (np.where(model_flux!=0)[0])
    #         wave = wave[np.where(model_flux!=0)[0]]
    #         flux = flux[np.where(model_flux!=0)[0]]
    #         model_flux = model_flux[np.where(model_flux!=0)[0]]
        wave = wave[buff:-buff]
        flux = flux[buff:-buff]
        model_flux = model_flux[buff:-buff]

        waveb = wave[0]
        waver = wave[-1]

        wave_og = og_data[0][(og_data[0]>=waveb) &(og_data[0]<=waver)]
        flux_og = og_data[1][(og_data[0]>=waveb) &(og_data[0]<=waver)]
        plt.figure(figsize=[16,8])
        plt.plot(wave_og,flux_og)
        plt.plot(wave,flux)
        plt.plot(wave,model_flux)
    #         plt.xlim(3700,8000)
    #         plt.ylim(.3,1.5)
        plt.show()
        plt.figure(figsize=[16,8])
        plt.plot(wave_og,flux_og)
        plt.plot(wave,flux)
        plt.plot(wave,model_flux)
        plt.xlim(6300,7000)
        plt.ylim(.3,1.5)
        plt.show()
        plt.figure(figsize=[16,8])
        plt.plot(wave_og,flux_og)
        plt.plot(wave,flux)
        plt.plot(wave,model_flux)
        plt.xlim(3500,4200)
        plt.ylim(.3,1.5)
        plt.show()
# Out:
# SN2016afk-combined-20180207_ap9_6.803_rkron.fits
# age: 10.48 Gyr
# [Z/H]: -1.27 dex
# log M/Msun: 10.21
# E(B-V): 0.0 mag

# %%
#old code before clipping
# os.chdir('/Users/msiebert/Documents/UCSC/Research/firefly_release/')
# from run import firefly
# from run import read_firefly
# save=True
# for spec in spectra:
#     if '3.0_kpc' in spec.meta_dict['FILENAME'] and '_SN' not in spec.meta_dict['FILENAME']:
#         print (spec.meta_dict['FILENAME'])
#         wave, flux, model_flux, params = read_firefly.main('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
#         hdu_fit = fits.open('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
#         fit_head=hdu_fit[1].header
#     #     fit data=hdu_fit[1].data
#         neb_emission = flux - model_flux

#         meta_dict_spec = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0] +'-spec'}
#         meta_dict_model = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0]+ '-model'}
#         db_spec = UCSC_db.spectrum(wavelength=wave, flux=flux, meta_dict=meta_dict_spec)
#         db_spec_model = UCSC_db.spectrum(wavelength=wave, flux=model_flux, meta_dict=meta_dict_model)
#         UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [6400, 6800], plot_region = [3550, 7900], legend = True, rescale=False, cont_subtract=False)
#         UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [6400, 6800], legend = False, rescale=False, cont_subtract=False)
#         UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [4800, 5030], legend = False, rescale=False, cont_subtract=False)
#         UCSC_db.host_line_plots([db_spec, db_spec_model], 0, region = [3550, 4150], legend = False, rescale=False, cont_subtract=False)

#         meta_dict_neb = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0]+ '-nebular'}
#         db_spec_neb = UCSC_db.spectrum(wavelength=wave, flux=neb_emission, meta_dict=meta_dict_neb)
#         UCSC_db.host_line_plots([db_spec_neb], 0, region = [6400, 6800], plot_region = [3550, 7900], legend = True, rescale=False)
#         UCSC_db.host_line_plots([db_spec_neb], 0, region = [6400, 6800], legend = False, rescale=False)
#         UCSC_db.host_line_plots([db_spec_neb], 0, region = [4800, 5030], legend = False, rescale=False)
#         UCSC_db.host_line_plots([db_spec_neb], 0, region = [3550, 4150], legend = False, rescale=False)

#         plt.figure(figsize=[15,8])
#         flux_filt = scipy.signal.medfilt(db_spec_neb.flux, kernel_size=201)
#         print ('Median continuum: ', np.median(db_spec.flux))
#         print ('Median residual: ', np.median(np.absolute(flux_filt)))
#         print ('Residual fraction: ', 100*np.median(np.absolute(flux_filt))/np.median(db_spec.flux), '%')
#         plt.plot(db_spec_neb.wavelength, db_spec_neb.flux)
#         plt.plot(db_spec_neb.wavelength, flux_filt)
#         # plt.xlim(6000,8000)
#     #     plt.ylim(-.05,.05)
#         plt.show()

#         plt.figure(figsize=[15,8])
#         final_neb_flux = db_spec_neb.flux - flux_filt
#         plt.plot(db_spec_neb.wavelength, final_neb_flux)
#         # plt.xlim(6000,8000)
#     #     plt.ylim(-.01,.105)
#         plt.xlim(3600,5100)
#         plt.axhline(y=0.0, color='k')
#         plt.show()

#     #     txt_header = 'wavelength flux fluxerr\n'
#     #     txt_header = txt_header + 'SN: {}\n'.format(spec.meta_dict['OBJECT'])
#     #     txt_header = txt_header + 'Age: {}\n'.format(params[0])
#     #     txt_header = txt_header + 'Stellar Z: {}\n'.format(params[1])
#     #     txt_header = txt_header + 'log M/Msun: {}\n'.format(params[2])
#     #     txt_header = txt_header + 'E(B-V): {}\n'.format(params[3])

#         if save:
#             outhdu=fits.PrimaryHDU([db_spec_neb.wavelength,final_neb_flux])
#             hdul=fits.HDUList(outhdu)
#             hdul[0].header=fit_head
#             hdul[0].verify('fix') 
#             hdul[0].header.set('redshift', z)
#             for key in spec.meta_dict.keys():
#                 hdul[0].header.set(key, spec.meta_dict.get(key,'N/A'))
#         #     hdul[0].header.set('ebv_host', ebv_gal)
#         #     hdul[0].header.set('h_ratio',h_ratio)
#             hdul.writeto('/Users/msiebert/Documents/UCSC/Research/Foundation_Hosts/analysis/host_nebular_emission_data/'+spec.meta_dict['FILENAME'].split('.fits')[0]+'-nebular.fits',overwrite=True)
#             hdul.close()
#     #     np.savetxt('/Users/msiebert/Documents/UCSC/Research/Foundation_Hosts/analysis/host_nebular_emission_data/'+spec.meta_dict['FILENAME'].split('.fits')[0]+'-nebular.flm',
#     #            np.transpose([db_spec_neb.wavelength,final_neb_flux]), header=txt_header)

# %%
test_query = "SELECT * from SPECTRA where FILENAME like '%combined%'"
spectra = UCSC_db.grab_all_spec_data(test_query)
# Out:
# Collecting data from ../UCSC_SPEC_DATA_DEV.db ...
# 2017hmf-combined-20180711_ap3_1.5_kpc.fits
# 2017hmf-combined-20180711_ap2_1.0_kpc_SN_BAD.fits
# PS15cge-combined-20180711_ap4_1.5_kpc_SN_BAD.fits
# PS15cge-combined-20180711_ap11_1.5_arcsec.fits
# 2017hmf-combined-20180711_ap5_2.0_kpc.fits
# ASASSN15pr-combined-20180711_ap8_1.0_arcsec_SN.fits
# PS15cge-combined-20180711_ap1_1.0_kpc_BAD.fits
# 2018dfy-combined-20180711_ap1.fits
# 2017hmf-combined-20180711_ap1_1.0_kpc_BAD.fits
# PS15cge-combined-20180711_ap12_1.5_arcsec_SN.fits
# ASASSN15pr-combined-20180711_ap9_1.5_arcsec.fits
# 2017hmf-combined-20180711_ap12_4.25_rkron.fits
# 2018bdm-combined-20180711_ap1.fits
# PS15cge-combined-20180711_ap3_1.5_kpc_BAD.fits
# 2017hmf-combined-20180711_ap4_1.5_kpc_SN.fits
# PS15cge-combined-20180711_ap15_3.0_arcsec.fits
# PS15cge-combined-20180711_ap16_3.0_arcsec_SN.fits
# 2017hmf-combined-20180711_ap10_2.0_arcsec.fits
# PS15cge-combined-20180711_ap8_3.0_kpc_SN.fits
# 2017hmf-combined-20180711_ap6_3.0_kpc.fits
# ASASSN15pr-combined-20180711_ap7_1.0_arcsec.fits
# 2018cdc-combined-20180711_ap1.fits
# 2017hmf-combined-20180711_ap9_1.5_arcsec.fits
# 2018cxk-combined-20180711_ap1.fits
# PS15cge-combined-20180711_ap5_2.0_kpc.fits
# ASASSN15pr-combined-20180711_ap1_1.0_kpc.fits
# PS15cge-combined-20180711_ap10_1.0_arcsec_SN.fits
# ASASSN15pr-combined-20180711_ap3_1.5_kpc.fits
# ASASSN15pr-combined-20180711_ap10_1.5_arcsec_SN.fits
# 2018cow-combined-20180711_ap1.fits
# ASASSN15pr-combined-20180711_ap5_2.0_kpc.fits
# ASASSN15pr-combined-20180711_ap2_1.0_kpc_SN.fits
# 2017fgc-combined-20180711_ap1.fits
# 2018agk-combined-20180711_ap1.fits
# ASASSN15pr-combined-20180711_ap12_2.0_arcsec_SN.fits
# ASASSN15pr-combined-20180711_ap11_2.0_arcsec.fits
# 2017hmf-combined-20180711_ap8_1.0_arcsec_SN.fits
# PS15cge-combined-20180711_ap2_1.0_kpc_SN_BAD.fits
# 2017hmf-combined-20180711_ap7_1.0_arcsec.fits
# 2018dfg-combined-20180711_ap1.fits
# 2018bwo-combined-20180711_ap1.fits
# ASASSN15pr-combined-20180711_ap4_1.5_kpc_SN.fits
# PS15cge-combined-20180711_ap7_3.0_kpc.fits
# PS15cge-combined-20180711_ap13_2.0_arcsec.fits
# ASASSN15pr-combined-20180711_ap6_3.0_kpc.fits
# ASASSN15pr-combined-20180711_ap14_12.76_rkron.fits
# PS15cge-combined-20180711_ap6_2.0_kpc_SN.fits
# ASASSN15pr-combined-20180711_ap13_3.0_arcsec.fits
# PS15cge-combined-20180711_ap14_2.0_arcsec_SN.fits
# 2017hmf-combined-20180711_ap11_3.0_arcsec.fits
# PS15cge-combined-20180711_ap17_7.4_rkron.fits
# PS15cge-combined-20180711_ap9_1.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap14_2.0_arcsec_SN.fits
# PTSS16-efw_1-combined-20180611_ap1_1.0_kpc.fits
# 2018jh_1-combined-20180611_ap9_1.0_arcsec_SN.fits
# 2017gfl-combined-20180611_ap9_1.0_arcsec.fits
# ASASSN15mg_1-combined-20180611_ap5_2.0_kpc.fits
# 2017hmf-combined-20180611_ap10_2.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap9_1.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap6_2.0_kpc_SN.fits
# 2018jh_1-combined-20180611_ap15_3.0_arcsec_SN.fits
# ASASSN15mg_1-combined-20180611_ap3_1.5_kpc.fits
# 2017gfl-combined-20180611_ap10_1.0_arcsec_SN.fits
# 2017hmf-combined-20180611_ap9_1.5_arcsec.fits
# 2017gfl-combined-20180611_ap6_2.0_kpc_SN.fits
# 2017gfl-combined-20180611_ap11_1.5_arcsec.fits
# ASASSN15mg_1-combined-20180611_ap2_1.0_kpc_SN.fits
# PTSS16-efw_1-combined-20180611_ap11_1.5_arcsec.fits
# ASASSN15mg_1-combined-20180611_ap12_3.0_arcsec.fits
# ASASSN15mg_1-combined-20180611_ap1_1.0_kpc.fits
# PTSS16-efw_1-combined-20180611_ap5_2.0_kpc.fits
# ASASSN15mg_1-combined-20180611_ap8_1.0_arcsec_SN.fits
# 2018jh_1-combined-20180611_ap2_1.0_kpc_SN.fits
# 2018jh_1-combined-20180611_ap13_2.0_arcsec_SN.fits
# 2017gfl-combined-20180611_ap1_1.0_kpc_BAD.fits
# PTSS16-efw_1-combined-20180611_ap3_1.5_kpc.fits
# 2017hmf-combined-20180611_ap12_4.25_rkron.fits
# 2017gfl-combined-20180611_ap2_1.0_kpc_SN_BAD.fits
# 2018jh_1-combined-20180611_ap11_1.5_arcsec_SN.fits
# 2018jh_1-combined-20180611_ap4_1.5_kpc_SN.fits
# 2017hmf-combined-20180611_ap1_1.0_kpc_BAD.fits
# AT2018cho-combined-20180611_ap1.fits
# 2018jh_1-combined-20180611_ap12_2.0_arcsec.fits
# 2017hmf-combined-20180611_ap7_1.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap7_3.0_kpc.fits
# 2017gfl-combined-20180611_ap14_2.0_arcsec_SN.fits
# ASASSN15mg_1-combined-20180611_ap11_2.0_arcsec.fits
# 2017gfl-combined-20180611_ap15_3.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap15_3.0_arcsec.fits
# ASASSN15mg_1-combined-20180611_ap6_3.0_kpc.fits
# ASASSN15mg_1-combined-20180611_ap4_1.5_kpc_SN.fits
# PTSS16-efw_1-combined-20180611_ap10_1.0_arcsec_SN.fits
# AT2018cew-combined-20180611_ap1.fits
# PTSS16-efw_1-combined-20180611_ap8_3.0_kpc_SN.fits
# 2018jh_1-combined-20180611_ap6_2.0_kpc_SN.fits
# 2017gfl-combined-20180611_ap8_3.0_kpc_SN.fits
# SN2018bdm-combined-20180611_ap1.fits
# 2017hmf-combined-20180611_ap11_3.0_arcsec.fits
# ASASSN15mg_1-combined-20180611_ap9_1.5_arcsec.fits
# 2018jh_1-combined-20180611_ap10_1.5_arcsec.fits
# 2017hmf-combined-20180611_ap6_3.0_kpc.fits
# ASASSN15mg_1-combined-20180611_ap10_1.5_arcsec_SN.fits
# AT2018cdc-combined-20180611_ap1.fits
# 2017gfl-combined-20180611_ap7_3.0_kpc.fits
# PTSS16-efw_1-combined-20180611_ap16_3.0_arcsec_SN.fits
# 2017gfl-combined-20180611_ap12_1.5_arcsec_SN.fits
# AT2018bcb-combined-20180611_ap1.fits
# 2017hmf-combined-20180611_ap8_1.0_arcsec_SN.fits
# 2018jh_1-combined-20180611_ap7_3.0_kpc.fits
# PTSS16-efw_1-combined-20180611_ap2_1.0_kpc_SN.fits
# PTSS16-efw_1-combined-20180611_ap12_1.5_arcsec_SN.fits
# PTSS16-efw_1-combined-20180611_ap17_10.4_rkron.fits
# 2017gfl-combined-20180611_ap3_1.5_kpc.fits
# 2018jh_1-combined-20180611_ap1_1.0_kpc.fits
# 2017gfl-combined-20180611_ap13_2.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap13_2.0_arcsec.fits
# 2017gfl-combined-20180611_ap4_1.5_kpc_SN.fits
# ASASSN15mg_1-combined-20180611_ap7_1.0_arcsec.fits
# PTSS16-efw_1-combined-20180611_ap4_1.5_kpc_SN.fits
# 2017gfl-combined-20180611_ap5_2.0_kpc.fits
# ASASSN15mg_1-combined-20180611_ap13_14.02_rkron.fits
# 2018jh_1-combined-20180611_ap5_2.0_kpc.fits
# 2018jh_1-combined-20180611_ap14_3.0_arcsec.fits
# 2017gfl-combined-20180611_ap16_9.47_rkron.fits
# 2017hmf-combined-20180611_ap3_1.5_kpc.fits
# AT2018cif-combined-20180611_ap1.fits
# 2018jh_1-combined-20180611_ap16_15.14_rkron.fits
# 2017hmf-combined-20180611_ap4_1.5_kpc_SN.fits
# 2017hmf-combined-20180611_ap5_2.0_kpc.fits
# 2018jh_1-combined-20180611_ap8_1.0_arcsec.fits
# 2017hmf-combined-20180611_ap2_1.0_kpc_SN_BAD.fits
# 2018jh_1-combined-20180611_ap3_1.5_kpc.fits
# 2017gav_host-combined-20180510_ap11_2.0_arcsec.fits
# SN2017hlt_host-combined-20180510_ap9_1.5_arcsec.fits
# SN2017hlt_host-combined-20180510_ap1_1.0_kpc.fits
# SN2017egm-combined-20180510_ap1.fits
# SN2018aoq-combined-20180510_ap1.fits
# at2018qb-combined-20180510_ap1.fits
# 2017gav_host-combined-20180510_ap6_3.0_kpc.fits
# SN2017hlt_host-combined-20180510_ap5_2.0_kpc.fits
# 2017gav_host-combined-20180510_ap13_3.0_arcsec.fits
# sn2018kl_host-combined-20180510_ap6_2.0_kpc_SN.fits
# SN2017hlt_host-combined-20180510_ap3_1.5_kpc.fits
# 2017gav_host-combined-20180510_ap4_1.5_kpc_SN.fits
# sn2018kl_host-combined-20180510_ap12_2.0_arcsec.fits
# AT2018bfc-combined-20180510_ap1.fits
# SN2018gj-combined-20180510_ap1.fits
# SN2017hlt_host-combined-20180510_ap6_3.0_kpc.fits
# SN2018zr_combined-20180510_ap1.fits
# SN2017hlt_host-combined-20180510_ap7_1.0_arcsec.fits
# 2017gav_host-combined-20180510_ap8_1.0_arcsec_SN.fits
# 2017gav_host-combined-20180510_ap2_1.0_kpc_SN.fits
# 2017gav_host-combined-20180510_ap1_1.0_kpc.fits
# sn2018kl_host-combined-20180510_ap8_1.0_arcsec.fits
# SN2018bdm-combined-20180510_ap1.fits
# 2017gav_host-combined-20180510_ap3_1.5_kpc.fits
# SN2018bek-combined-20180510_ap1.fits
# sn2018gv-combined-20180510_ap1.fits
# 2017gav_host-combined-20180510_ap5_2.0_kpc.fits
# sn2018kl_host-combined-20180510_ap11_1.5_arcsec_SN.fits
# SN2017hlt_host-combined-20180510_ap2_1.0_kpc_SN.fits
# sn2018kl_host-combined-20180510_ap14_2.83_rkron.fits
# 2017gav_host-combined-20180510_ap7_1.0_arcsec.fits
# SN2017hlt_host-combined-20180510_ap11_2.0_arcsec.fits
# 2017gav_host-combined-20180510_ap14_3.14_rkron.fits
# SN2017eaw-combined-20180510_ap1.fits
# sn2018kl_host-combined-20180510_ap9_1.0_arcsec_SN.fits
# sn2018kl_host-combined-20180510_ap1_1.0_kpc_BAD.fits
# sn2018kl_host-combined-20180510_ap2_1.0_kpc_SN_BAD.fits
# sn2018kl_host-combined-20180510_ap7_3.0_kpc.fits
# SN2017hlt_host-combined-20180510_ap10_1.5_arcsec_SN.fits
# SN2017hlt_host-combined-20180510_ap13_3.0_arcsec.fits
# sn2018kl_host-combined-20180510_ap13_3.0_arcsec.fits
# 2017gav_host-combined-20180510_ap10_1.5_arcsec_SN.fits
# SN2017hlt_host-combined-20180510_ap12_2.0_arcsec_SN.fits
# 2017gav_host-combined-20180510_ap12_2.0_arcsec_SN.fits
# 2017gav_host-combined-20180510_ap9_1.5_arcsec.fits
# sn2018kl_host-combined-20180510_ap4_1.5_kpc_SN.fits
# SN2017hlt_host-combined-20180510_ap4_1.5_kpc_SN.fits
# sn2018kl_host-combined-20180510_ap5_2.0_kpc.fits
# SN2017hlt_host-combined-20180510_ap15_6.02_rkron.fits
# sn2018kl_host-combined-20180510_ap10_1.5_arcsec.fits
# SN2017hlt_host-combined-20180510_ap14_3.0_arcsec_SN.fits
# SN2018agk-combined-20180510_ap1.fits
# sn2018kl_host-combined-20180510_ap3_1.5_kpc.fits
# SN2017hlt_host-combined-20180510_ap8_1.0_arcsec_SN.fits
# SN2017erp-combined-20180510_ap1.fits
# ATLAS17jxd-combined-20180116_ap4_1.5_kpc_SN_BAD.fits
# ATLAS17jxd-combined-20180116_ap8_3.0_kpc_SN.fits
# PS16ez-combined-20180116_ap3_1.5_kpc_BAD.fits
# PS16ez-combined-20180116_ap16_3.0_arcsec_SN.fits
# ATLAS17dzg-combined-20180116_ap7_3.0_kpc.fits
# PS16ez-combined-20180116_ap15_3.0_arcsec.fits
# ATLAS17jxd-combined-20180116_ap9_2.67_rkron.fits
# PS16ez-combined-20180116_ap12_1.5_arcsec_SN.fits
# PS16ez-combined-20180116_ap8_3.0_kpc_SN.fits
# ATLAS17dzg-combined-20180116_ap1_1.0_kpc_BAD.fits
# PS16ez-combined-20180116_ap11_1.5_arcsec.fits
# PS16ez-combined-20180116_ap1_1.0_kpc_BAD.fits
# ATLAS17dzg-combined-20180116_ap5_2.0_kpc.fits
# PS16ez-combined-20180116_ap4_1.5_kpc_SN_BAD.fits
# ATLAS17dzg-combined-20180116_ap6_2.0_kpc_SN.fits
# ATLAS17dzg-combined-20180116_ap3_1.5_kpc.fits
# PS16ez-combined-20180116_ap14_2.0_arcsec_SN.fits
# ATLAS17jxd-combined-20180116_ap1_1.0_kpc_BAD.fits
# ATLAS17jxd-combined-20180116_ap6_2.0_kpc_SN.fits
# PS16ez-combined-20180116_ap7_3.0_kpc.fits
# PS16ez-combined-20180116_ap13_2.0_arcsec.fits
# PS16ez-combined-20180116_ap2_1.0_kpc_SN_BAD.fits
# ATLAS17dzg-combined-20180116_ap4_1.5_kpc_SN.fits
# ATLAS17jxd-combined-20180116_ap5_2.0_kpc.fits
# PS16ez-combined-20180116_ap6_2.0_kpc_SN.fits
# ATLAS17jxd-combined-20180116_ap2_1.0_kpc_SN_BAD.fits
# PS16ez-combined-20180116_ap5_2.0_kpc.fits
# PS16ez-combined-20180116_ap17_7.51_rkron.fits
# PS16ez-combined-20180116_ap9_1.0_arcsec.fits
# PS16ez-combined-20180116_ap10_1.0_arcsec_SN.fits
# ATLAS17jxd-combined-20180116_ap7_3.0_kpc.fits
# ATLAS17dzg-combined-20180116_ap8_3.0_kpc_SN.fits
# ATLAS17jxd-combined-20180116_ap3_1.5_kpc_BAD.fits
# ATLAS17dzg-combined-20180116_ap2_1.0_kpc_SN_BAD.fits
# ATLAS17dzg-combined-20180116_ap9_7.25_rkron.fits
# AT2017hoo-combined-20180115_ap1.fits
# PS15mt-combined-20180115_ap4_1.5_kpc_SN.fits
# AT2017hoo-combined-20180115_ap7_3.0_kpc.fits
# PS15mt-combined-20180115_ap1_1.0_kpc_BAD.fits
# AT2017hoo-combined-20180115_ap3_1.5_kpc.fits
# ASASSN15pn-combined-20180115_ap6_2.0_kpc_SN.fits
# ASASSN15pn-combined-20180115_ap9_5.45_rkron.fits
# AT2017hoo-combined-20180115_ap5_2.0_kpc.fits
# PS15mt-combined-20180115_ap8_3.0_kpc_SN.fits
# AT2017hju-combined-20180115_ap1.fits
# PS15mt-combined-20180115_ap9_6.14_rkron.fits
# ASASSN15pn-combined-20180115_ap4_1.5_kpc_SN.fits
# ASASSN15pn-combined-20180115_ap1_1.0_kpc.fits
# ASASSN15pn-combined-20180115_ap3_1.5_kpc.fits
# ASASSN15pn-combined-20180115_ap5_2.0_kpc.fits
# PS15mt-combined-20180115_ap7_3.0_kpc.fits
# AT2017hoo_SN-combined-20180115_ap1.fits
# PS15mt-combined-20180115_ap6_2.0_kpc_SN.fits
# AT2017hoo-combined-20180115_ap1_1.0_kpc_BAD.fits
# AT2017hoo-combined-20180115_ap9_7.54_rkron.fits
# ASASSN15pn-combined-20180115_ap8_3.0_kpc_SN.fits
# PS15mt-combined-20180115_ap3_1.5_kpc.fits
# PS15mt-combined-20180115_ap2_1.0_kpc_SN_BAD.fits
# ASASSN15pn-combined-20180115_ap2_1.0_kpc_SN.fits
# AT2017glq-combined-20180115_ap1.fits
# ASASSN15pn-combined-20180115_ap7_3.0_kpc.fits
# PS15mt-combined-20180115_ap5_2.0_kpc.fits
# SN2016cuv-combined-20170824_ap7_3.0_kpc.fits
# PS16cvc-combined-20170824_ap8_3.0_kpc_SN.fits
# ATLAS16bwu-combined-20170824_ap5_2.0_kpc.fits
# CSS161013-combined-20170824_ap7_3.0_kpc.fits
# PS15cfn-combined-20170824_ap6_2.0_kpc_SN_BAD.fits
# PS16cvc-combined-20170824_ap7_3.0_kpc.fits
# ATLAS16bwu-combined-20170824_ap1_1.0_kpc_BAD.fits
# SN2016grz-combined-20170824_ap3_1.5_kpc_BAD.fits
# ATLAS16bwu-combined-20170824_ap3_1.5_kpc.fits
# CSS161013-combined-20170824_ap1_1.0_kpc_BAD.fits
# PS16dnp-combined-20170824_ap6_2.0_kpc_SN.fits
# PS16dnp-combined-20170824_ap1_1.0_kpc_BAD.fits
# CSS161013-combined-20170824_ap4_1.5_kpc_SN.fits
# SN2016grz-combined-20170824_ap5_2.0_kpc.fits
# PS15cfn-combined-20170824_ap8_3.0_kpc_SN.fits
# SN2016cuv-combined-20170824_ap3_1.5_kpc_BAD.fits
# PS16cvc-combined-20170824_ap2_1.0_kpc_SN.fits
# SN2016cuv-combined-20170824_ap1_1.0_kpc_BAD.fits
# PS16cvc-combined-20170824_ap3_1.5_kpc.fits
# SN2016grz-combined-20170824_ap2_1.0_kpc_SN_BAD.fits
# SN2016cuv-combined-20170824_ap5_2.0_kpc.fits
# CSS161013-combined-20170824_ap5_2.0_kpc.fits
# ATLAS16bwu-combined-20170824_ap7_3.0_kpc.fits
# CSS161013-combined-20170824_ap9_3.17_rkron.fits
# PS16cvc-combined-20170824_ap4_1.5_kpc_SN.fits
# PS15cfn-combined-20170824_ap9_3.8_rkron.fits
# PS16cvc-combined-20170824_ap5_2.0_kpc.fits
# SN2016cuv-combined-20170824_ap4_1.5_kpc_SN_BAD.fits
# SN2016grz-combined-20170824_ap8_3.0_kpc_SN.fits
# CSS161013-combined-20170824_ap3_1.5_kpc.fits
# PS15cfn-combined-20170824_ap2_1.0_kpc_SN_BAD.fits
# SN2016cuv-combined-20170824_ap8_3.0_kpc_SN.fits
# ATLAS16bwu-combined-20170824_ap9_9.04_rkron.fits
# SN2016grz-combined-20170824_ap1_1.0_kpc_BAD.fits
# PS16cvc-combined-20170824_ap1_1.0_kpc.fits
# SN2016grz-combined-20170824_ap7_3.0_kpc.fits
# CSS161013-combined-20170824_ap8_3.0_kpc_SN.fits
# SN2016grz-combined-20170824_ap4_1.5_kpc_SN_BAD.fits
# PS15cfn-combined-20170824_ap7_3.0_kpc.fits
# PS16dnp-combined-20170824_ap2_1.0_kpc_SN_BAD.fits
# PS15cfn-combined-20170824_ap4_1.5_kpc_SN_BAD.fits
# PS16dnp-combined-20170824_ap7_3.0_kpc.fits
# SN2016cuv-combined-20170824_ap2_1.0_kpc_SN_BAD.fits
# PS16cvc-combined-20170824_ap6_2.0_kpc_SN.fits
# PS15cfn-combined-20170824_ap5_2.0_kpc_BAD.fits
# SN2016cuv-combined-20170824_ap9_6.53_rkron.fits
# PS15cfn-combined-20170824_ap3_1.5_kpc_BAD.fits
# PS16cvc-combined-20170824_ap9_11.24_rkron.fits
# PS16dnp-combined-20170824_ap8_3.0_kpc_SN.fits
# PS16dnp-combined-20170824_ap3_1.5_kpc.fits
# SN2016grz-combined-20170824_ap6_2.0_kpc_SN.fits
# PS16dnp-combined-20170824_ap9_3.09_rkron.fits
# PS16dnp-combined-20170824_ap5_2.0_kpc.fits
# PS15cfn-combined-20170824_ap1_1.0_kpc_BAD.fits
# CSS161013-combined-20170824_ap6_2.0_kpc_SN.fits
# PS16dnp-combined-20170824_ap4_1.5_kpc_SN.fits
# SN2016grz-combined-20170824_ap9_4.2_rkron.fits
# CSS161013-combined-20170824_ap2_1.0_kpc_SN_BAD.fits
# SN2016cuv-combined-20170824_ap6_2.0_kpc_SN.fits
# ASASSN15fa-combined-20170403_ap1_1.0_kpc.fits
# ASASSN15fa-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN15fa-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15fa-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15fa-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15fa-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15fa-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15fa-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15fa-combined-20170403_ap9_24.63_rkron.fits
# ASASSN15hg-combined-20170403_ap1_1.0_kpc.fits
# ASASSN15hg-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN15hg-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15hg-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15hg-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15hg-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15hg-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15hg-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15hg-combined-20170403_ap9_13.82_rkron.fits
# ASASSN15jt-combined-20170403_ap1_1.0_kpc.fits
# ASASSN15jt-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN15jt-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15jt-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15jt-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15jt-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15jt-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15jt-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15jt-combined-20170403_ap9_17.69_rkron.fits
# ASASSN15la-combined-20170403_ap1_1.0_kpc.fits
# ASASSN15la-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN15la-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15la-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15la-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15la-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15la-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15la-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15la-combined-20170403_ap9_21.47_rkron.fits
# ASASSN15lu-combined-20170403_ap1_1.0_kpc_BAD.fits
# ASASSN15lu-combined-20170403_ap2_1.0_kpc_SN_BAD.fits
# ASASSN15lu-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15lu-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15lu-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15lu-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15lu-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15lu-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15lu-combined-20170403_ap9_7.87_rkron.fits
# ASASSN15mi-combined-20170403_ap1_1.0_kpc_BAD.fits
# ASASSN15mi-combined-20170403_ap2_1.0_kpc_SN_BAD.fits
# ASASSN15mi-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15mi-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15mi-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15mi-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15mi-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15mi-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15mi-combined-20170403_ap9_7.62_rkron.fits
# ASASSN15nr-combined-20170403_ap1_1.0_kpc.fits
# ASASSN15nr-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN15nr-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15nr-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15nr-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15nr-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15nr-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15nr-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15nr-combined-20170403_ap9_14.54_rkron.fits
# ASASSN15so-combined-20170403_ap1_1.0_kpc.fits
# ASASSN15so-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN15so-combined-20170403_ap3_1.5_kpc.fits
# ASASSN15so-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN15so-combined-20170403_ap5_2.0_kpc.fits
# ASASSN15so-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN15so-combined-20170403_ap7_3.0_kpc.fits
# ASASSN15so-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN15so-combined-20170403_ap9_24.66_rkron.fits
# ASASSN16av-combined-20170403_ap1_1.0_kpc.fits
# ASASSN16av-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN16av-combined-20170403_ap3_1.5_kpc.fits
# ASASSN16av-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN16av-combined-20170403_ap5_2.0_kpc.fits
# ASASSN16av-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN16av-combined-20170403_ap7_3.0_kpc.fits
# ASASSN16av-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN16av-combined-20170403_ap9_23.81_rkron.fits
# ASASSN16lg-combined-20170403_ap1_1.0_kpc.fits
# ASASSN16lg-combined-20170403_ap2_1.0_kpc_SN.fits
# ASASSN16lg-combined-20170403_ap3_1.5_kpc.fits
# ASASSN16lg-combined-20170403_ap4_1.5_kpc_SN.fits
# ASASSN16lg-combined-20170403_ap5_2.0_kpc.fits
# ASASSN16lg-combined-20170403_ap6_2.0_kpc_SN.fits
# ASASSN16lg-combined-20170403_ap7_3.0_kpc.fits
# ASASSN16lg-combined-20170403_ap8_3.0_kpc_SN.fits
# ASASSN16lg-combined-20170403_ap9_15.99_rkron.fits
# AT2017cfb-combined-20170403_ap1.fits
# ATLAS16cpu-combined-20170403_ap1_1.0_kpc.fits
# ATLAS16cpu-combined-20170403_ap2_1.0_kpc_SN.fits
# ATLAS16cpu-combined-20170403_ap3_1.5_kpc.fits
# ATLAS16cpu-combined-20170403_ap4_1.5_kpc_SN.fits
# ATLAS16cpu-combined-20170403_ap5_2.0_kpc.fits
# ATLAS16cpu-combined-20170403_ap6_2.0_kpc_SN.fits
# ATLAS16cpu-combined-20170403_ap7_3.0_kpc.fits
# ATLAS16cpu-combined-20170403_ap8_3.0_kpc_SN.fits
# ATLAS16cpu-combined-20170403_ap9_19.94_rkron.fits
# PS15bdr-combined-20170403_ap1_1.0_kpc_BAD.fits
# PS15bdr-combined-20170403_ap2_1.0_kpc_SN_BAD.fits
# PS15bdr-combined-20170403_ap3_1.5_kpc_BAD.fits
# PS15bdr-combined-20170403_ap4_1.5_kpc_SN_BAD.fits
# PS15bdr-combined-20170403_ap5_2.0_kpc_BAD.fits
# PS15bdr-combined-20170403_ap6_2.0_kpc_SN_BAD.fits
# PS15bdr-combined-20170403_ap7_3.0_kpc.fits
# PS15bdr-combined-20170403_ap8_3.0_kpc_SN.fits
# PS15bdr-combined-20170403_ap9_9.01_rkron.fits
# PS15zn-combined-20170403_ap1_1.0_kpc_BAD.fits
# PS15zn-combined-20170403_ap2_1.0_kpc_SN_BAD.fits
# PS15zn-combined-20170403_ap3_1.5_kpc_BAD.fits
# PS15zn-combined-20170403_ap4_1.5_kpc_SN_BAD.fits
# PS15zn-combined-20170403_ap5_2.0_kpc.fits
# PS15zn-combined-20170403_ap6_2.0_kpc_SN.fits
# PS15zn-combined-20170403_ap7_3.0_kpc.fits
# PS15zn-combined-20170403_ap8_3.0_kpc_SN.fits
# PS15zn-combined-20170403_ap9_6.85_rkron.fits
# PS16cqa-combined-20170403_ap1_1.0_kpc_BAD.fits
# PS16cqa-combined-20170403_ap2_1.0_kpc_SN_BAD.fits
# PS16cqa-combined-20170403_ap3_1.5_kpc.fits
# PS16cqa-combined-20170403_ap4_1.5_kpc_SN.fits
# PS16cqa-combined-20170403_ap5_2.0_kpc.fits
# PS16cqa-combined-20170403_ap6_2.0_kpc_SN.fits
# PS16cqa-combined-20170403_ap7_3.0_kpc.fits
# PS16cqa-combined-20170403_ap8_3.0_kpc_SN.fits
# PS16cqa-combined-20170403_ap9_15.96_rkron.fits
# PS16el-combined-20170403_ap1_1.0_kpc_BAD.fits
# PS16el-combined-20170403_ap2_1.0_kpc_SN_BAD.fits
# PS16el-combined-20170403_ap3_1.5_kpc.fits
# PS16el-combined-20170403_ap4_1.5_kpc_SN.fits
# PS16el-combined-20170403_ap5_2.0_kpc.fits
# PS16el-combined-20170403_ap6_2.0_kpc_SN.fits
# PS16el-combined-20170403_ap7_3.0_kpc.fits
# PS16el-combined-20170403_ap8_3.0_kpc_SN.fits
# PS16el-combined-20170403_ap9_6.83_rkron.fits
# PSNJ0859349-combined-20170403_ap1_1.0_kpc.fits
# PSNJ0859349-combined-20170403_ap2_1.0_kpc_SN.fits
# PSNJ0859349-combined-20170403_ap3_1.5_kpc.fits
# PSNJ0859349-combined-20170403_ap4_1.5_kpc_SN.fits
# PSNJ0859349-combined-20170403_ap5_2.0_kpc.fits
# PSNJ0859349-combined-20170403_ap6_2.0_kpc_SN.fits
# PSNJ0859349-combined-20170403_ap7_3.0_kpc.fits
# PSNJ0859349-combined-20170403_ap8_3.0_kpc_SN.fits
# PSNJ0859349-combined-20170403_ap9_17.56_rkron.fits
# PSNJ1602512-combined-20170403_ap2_1.0_kpc_SN.fits
# PSNJ1602512-combined-20170403_ap4_1.5_kpc_SN.fits
# PSNJ1602512-combined-20170403_ap6_2.0_kpc_SN.fits
# PSNJ1602512-combined-20170403_ap8_3.0_kpc_SN.fits
# PSNJ1628383-combined-20170403_ap1_1.0_kpc.fits
# PSNJ1628383-combined-20170403_ap2_1.0_kpc_SN.fits
# PSNJ1628383-combined-20170403_ap3_1.5_kpc.fits
# PSNJ1628383-combined-20170403_ap4_1.5_kpc_SN.fits
# PSNJ1628383-combined-20170403_ap5_2.0_kpc.fits
# PSNJ1628383-combined-20170403_ap6_2.0_kpc_SN.fits
# PSNJ1628383-combined-20170403_ap7_3.0_kpc.fits
# PSNJ1628383-combined-20170403_ap8_3.0_kpc_SN.fits
# PSNJ1628383-combined-20170403_ap9_34.67_rkron.fits
# 466 Total Spectra found

# %%
for spec in spectra:
    print (spec.meta_dict['FILENAME'])
    wave, flux, model_flux, params = read_firefly.main('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
    hdu_fit = fits.open('output/spFly-' + spec.meta_dict['FILENAME'].split('.fits')[0]+ '.fits')
    fit_head=hdu_fit[1].header
#     fit data=hdu_fit[1].data
    roi = (wave > 3650) & (wave < 6800)
    wave = wave[roi]
    flux = flux[roi]
    model_flux = model_flux[roi]
    
    nan_roi = (wave > 5135) & (wave < 5145)
    flux[nan_roi] = np.nan
    neb_emission = flux - model_flux
    
    
    
    meta_dict_spec = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0] +'-spec'}
    meta_dict_model = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0]+ '-model'}
    db_spec = UCSC_db.spectrum(wavelength=wave, flux=flux, meta_dict=meta_dict_spec)
    db_spec_model = UCSC_db.spectrum(wavelength=wave, flux=model_flux, meta_dict=meta_dict_model)
    meta_dict_neb = {'FILENAME': spec.meta_dict['FILENAME'].split('.fits')[0]+ '-nebular'}
    db_spec_neb = UCSC_db.spectrum(wavelength=wave, flux=neb_emission, meta_dict=meta_dict_neb)
    UCSC_db.host_line_plots_fancy([db_spec, db_spec_model], 0, neb = db_spec_neb, region = [6400, 6900], plot_region = [3550, 6900], legend = False, rescale=False, cont_subtract=False)
#     UCSC_db.host_line_plots_fancy([db_spec, db_spec_model], 0, neb = db_spec_neb, region = [5100, 5200], plot_region = [6500, 6800], legend = False, rescale=False, cont_subtract=False)
# Out:
# SN2016afk-combined-20180207_ap1_1.0_kpc_BAD.fits
# age: 7.65 Gyr
# [Z/H]: -1.62 dex
# log M/Msun: 9.6
# E(B-V): 0.13 mag
# SN2016afk-combined-20180207_ap2_1.0_kpc_SN_BAD.fits
# age: 6.27 Gyr
# [Z/H]: -0.46 dex
# log M/Msun: 9.43
# E(B-V): 0.09 mag
# SN2016afk-combined-20180207_ap3_1.5_kpc.fits
# age: 5.93 Gyr
# [Z/H]: -1.62 dex
# log M/Msun: 9.7
# E(B-V): 0.09 mag
# SN2016afk-combined-20180207_ap4_1.5_kpc_SN.fits
# age: 3.0 Gyr
# [Z/H]: -0.62 dex
# log M/Msun: 9.4
# E(B-V): 0.06 mag
# SN2016afk-combined-20180207_ap5_2.0_kpc.fits
# age: 6.49 Gyr
# [Z/H]: -0.62 dex
# log M/Msun: 9.78
# E(B-V): 0.07 mag
# SN2016afk-combined-20180207_ap6_2.0_kpc_SN.fits
# age: 3.0 Gyr
# [Z/H]: -0.36 dex
# log M/Msun: 9.67
# E(B-V): 0.16 mag
# SN2016afk-combined-20180207_ap7_3.0_kpc.fits
# age: 5.07 Gyr
# [Z/H]: -1.33 dex
# log M/Msun: 9.87
# E(B-V): 0.06 mag
# SN2016afk-combined-20180207_ap8_3.0_kpc_SN.fits
# age: 5.54 Gyr
# [Z/H]: -1.62 dex
# log M/Msun: 9.86
# E(B-V): 0.07 mag
# SN2016afk-combined-20180207_ap9_6.803_rkron.fits
# age: 11.0 Gyr
# [Z/H]: -1.01 dex
# log M/Msun: 10.19
# E(B-V): 0.04 mag

# %%
print (fit_head)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                   32 / length of dimension 1                          NAXIS2  =                 2781 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                    4 / number of table fields                         TTYPE1  = 'wavelength'                                                          TFORM1  = 'D       '                                                            TUNIT1  = 'Angstrom'                                                            TTYPE2  = 'original_data'                                                       TFORM2  = 'D       '                                                            TUNIT2  = '1e-17erg/s/cm2/Angstrom'                                             TTYPE3  = 'flux_error'                                                          TFORM3  = 'D       '                                                            TUNIT3  = '1e-17erg/s/cm2/Angstrom'                                             TTYPE4  = 'firefly_model'                                                       TFORM4  = 'D       '                                                            TUNIT4  = '1e-17erg/s/cm2/Angstrom'                                             HIERARCH redshift =  0.04565181121489412                                        HIERARCH Age_unit = 'log (age/Gyr)'                                             HIERARCH Metallicity_unit = '[Z/H]   '                                          HIERARCH Mass_unit = 'log (M/Msun)'                                             HIERARCH SSP_sfr = 'log (M*/Age(Gyr))'                                          IMF     = 'Kroupa  '                                                            MODEL   = 'E-MaStar'                                                            HIERARCH converged = 'True    '                                                 HIERARCH age_lightW = 0.6497740821759652                                        HIERARCH age_lightW_up_1sig = 0.8398243957800039                                HIERARCH age_lightW_low_1sig = 0.2945792823279749                               HIERARCH age_lightW_up_2sig = 0.8710772359997326                                HIERARCH age_lightW_low_2sig = 0.2336338516259031                               HIERARCH age_lightW_up_3sig = 0.8834634255387492                                HIERARCH age_lightW_low_3sig = 0.2336338516259031                               HIERARCH metallicity_lightW = -0.3937676456402943                               HIERARCH metallicity_lightW_up_1sig = -0.3858359408258681                       HIERARCH metallicity_lightW_low_1sig = -1.615560666418854                       HIERARCH metallicity_lightW_up_2sig = -0.3858359408258681                       HIERARCH metallicity_lightW_low_2sig = -2.029305646265938                       HIERARCH metallicity_lightW_up_3sig = -0.3482149312881044                       HIERARCH metallicity_lightW_low_3sig = -2.029305646265938                       HIERARCH age_massW = 0.8785512587398318                                         HIERARCH age_massW_up_1sig = 0.9967529581439069                                 HIERARCH age_massW_low_1sig = 0.2945792823279749                                HIERARCH age_massW_up_2sig = 1.032840802599742                                  HIERARCH age_massW_low_2sig = 0.2549135571830119                                HIERARCH age_massW_up_3sig = 1.032840802599742                                  HIERARCH age_massW_low_3sig = 0.2549135571830119                                HIERARCH metallicity_massW = -0.6927551722802424                                 ...
