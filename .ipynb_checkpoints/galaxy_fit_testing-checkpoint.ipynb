# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import sqlite3 as sq3
import bagpipes as pipes
import UCSC_spec_db_interaction as UCSC_db

# %%
def bin(spectrum, binn):
    """ Bins up two or three column spectral data by a specified factor. """

    binn = int(binn)
    nbins = len(spectrum)/binn
    binspec = np.zeros((nbins, spectrum.shape[1]))

    for i in range(binspec.shape[0]):
        spec_slice = spectrum[i*binn:(i+1)*binn, :]
        binspec[i, 0] = np.mean(spec_slice[:, 0])
        binspec[i, 1] = np.mean(spec_slice[:, 1])

        if spectrum.shape[1] == 3:
            binspec[i,2] = (1./float(binn)
                            *np.sqrt(np.sum(spec_slice[:, 2]**2)))

    return binspec


def load_kpora_spec(spec):
    """ Loads kaepora spectroscopic data """
    
    wavelength = kpora_spec.wavelength
    flux = kpora_spec.flux*10e-15
    err = kpora_spec.err*10e-15
    
    mask = (wavelength > 3500.) & (wavelength < 8000.)
    spectrum = np.c_[wavelength[mask],
                     flux[mask],
                     err[mask]]

    return bin(spectrum[mask], 2)

# %%
test_query = "SELECT * from SPECTRA where OBJECT like '%16-efw%' and FILENAME like '%combined%' and IS_KRON_RAD"
spectra = UCSC_db.query_and_plot(test_query)
# Out:
# Collecting data from ../UCSC_SPEC_DATA_DEV.db ...
# PTSS16-efw_1-combined-20180611_ap17_10.4_rkron.fits
# 1 Total Spectra found

# %%
for kpora_spec in spectra:
#     ID_number = "0001"
    galaxy = pipes.galaxy(kpora_spec, load_kpora_spec, photometry_exists=False)

    fig = galaxy.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-73e653974126> in <module>
#       1 for spec in spectra:
#       2     ID_number = "0001"
# ----> 3     galaxy = pipes.galaxy(spec, load_kpora_spec, photometry_exists=False)
#       4
#       5     fig = galaxy.plot()
#
# ~/anaconda3/lib/python3.7/site-packages/bagpipes/input/galaxy.py in __init__(self, ID, load_data, spec_units, phot_units, spectrum_exists, photometry_exists, filt_list, out_units, load_indices, index_list, index_redshift, input_spec_cov_matrix)
#      96
#      97             elif spectrum_exists and not photometry_exists:
# ---> 98                 self.spectrum = load_data(self.ID)
#      99
#     100             elif photometry_exists and not spectrum_exists:
#
# <ipython-input-20-b71ce7886bd9> in load_kpora_spec(spec)
#      21     """ Loads kaepora spectroscopic data """
#      22
# ---> 23     wavelength = kpora_spec.wavelength
#      24     flux = kpora_spec.flux*10e-15
#      25     err = kpora_spec.err*10e-15
#
# NameError: name 'kpora_spec' is not defined
